# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=927cb5dd4ae4cdec9e69dad274f537f2&language=en-US&page=1")

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#    'genre_ids': [35, 10749],
#    'id': 1632181,
#    'title': 'Accidental Partners',
#    'original_language': 'es',
#    'original_title': 'Socias por accidente',
#    'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#    'popularity': 25.974,
#    'poster_path': '/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg',
#    'release_date': '2026-03-12',
#    'softcore': False,
#    'video': False,
#    'vote_average': 9.051,
#    'vote_count': 311},
#   {'adult': False,
#    'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#    'genre_ids': [12, 16, 10751, 14],
#    'id': 1007757,
#    'title': 'Swapped',
#    'original_language': 'en',
#    'original_title': 'Swapped',
# ...

# %%
response.json()["results"]
# Out:
# [{'adult': False,
#   'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#   'genre_ids': [35, 10749],
#   'id': 1632181,
#   'title': 'Accidental Partners',
#   'original_language': 'es',
#   'original_title': 'Socias por accidente',
#   'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#   'popularity': 25.974,
#   'poster_path': '/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg',
#   'release_date': '2026-03-12',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.051,
#   'vote_count': 311},
#  {'adult': False,
#   'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#   'genre_ids': [12, 16, 10751, 14],
#   'id': 1007757,
#   'title': 'Swapped',
#   'original_language': 'en',
#   'original_title': 'Swapped',
# ...

# %%
pd.DataFrame(response.json()["results"])
# Out:
#     adult                     backdrop_path            genre_ids       id  \
# 0   False  /iCML6fBe3X0y06P33bM7dyYXPKZ.jpg          [35, 10749]  1632181
# 1   False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 2   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
# 3   False  /xBT0oNq6rsTFv4SxG5uGRIEOrq6.jpg          [10402, 18]   936075
# 4   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg             [18, 80]      238
# 5   False  /fFyLcR22R4ynrecqjMniKXm0UTp.jpg            [878, 12]   687163
# 6   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]      240
# 7   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg      [18, 36, 10752]      424
# 8   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                 [18]      389
# 9   False  /bVGHSe47W6oCQL1Q88pvRAet51A.jpg           [18, 9648]  1330021
# 10  False  /dyJvKsNs2KP8qQnAXbRwDjblViy.jpg      [16, 10751, 14]      129
# 11  False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg         [28, 80, 53]      155
# ...

# %%
pd.DataFrame(response.json()["results"]).head(6)[["id","title", "overview", "release_date", "popularity", "vote_average", "vote_count"]]
# Out:
#         id                     title  \
# 0  1632181       Accidental Partners
# 1  1007757                   Swapped
# 2      278  The Shawshank Redemption
# 3   936075                   Michael
# 4      238             The Godfather
# 5   687163         Project Hail Mary
#
#                                             overview release_date  popularity  \
# 0  Two women discover they were both scammed by t...   2026-03-12     25.9740
# 1  A small woodland creature and a majestic bird,...   2026-05-01     77.5193
# 2  Imprisoned in the 1940s for the double murder ...   1994-09-23     91.0922
# 3  The story of Michael Jackson, one of the most ...   2026-04-22    155.4839
# 4  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     32.7203
# 5  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    158.8848
#
#    vote_average  vote_count
# 0         9.051         311
# 1         8.919        1953
# 2         8.726       30783
# 3         8.703        3542
# ...

# %%
df = pd.DataFrame()

# %%
dfs = []

for i in range(1, 501):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=927cb5dd4ae4cdec9e69dad274f537f2&language=en-US&page={}".format(i))
    temp_df = pd.DataFrame(response.json()["results"])[["id","title", "overview", "release_date", "popularity", "vote_average", "vote_count"]]

    dfs.append(temp_df)

df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#            id                                       title  \
# 0     1632181                         Accidental Partners
# 1     1007757                                     Swapped
# 2         278                    The Shawshank Redemption
# 3      936075                                     Michael
# 4         238                               The Godfather
# ...       ...                                         ...
# 9995   748853                                In the Earth
# 9996   207769                             Banshee Chapter
# 9997   164251                                      Serena
# 9998    16889  Revenge of the Nerds II: Nerds in Paradise
# 9999    40805                            The Green Hornet
#
#                                                overview release_date  \
# 0     Two women discover they were both scammed by t...   2026-03-12
# 1     A small woodland creature and a majestic bird,...   2026-05-01
# ...

# %%
df.to_csv("movies.csv")
