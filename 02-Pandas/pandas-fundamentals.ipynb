# %%
import pandas as pd

# %%
#Series (Single Column)
cgpa = pd.Series([8.2,7.4,9.1])
cgpa
# Out:
# 0    8.2
# 1    7.4
# 2    9.1
# dtype: float64

# %%
#DataFrame (Multiple Columns)
df = pd.DataFrame({
    "Name" : ["Alice", "Bob", "John"],
    "CGPA" : [8.2, 7.4, 9.1],
    "Package" : [12, 8, 18]
})

# %%
df
# Out:
#     Name  CGPA  Package
# 0  Alice   8.2       12
# 1    Bob   7.4        8
# 2   John   9.1       18

# %%
df["CGPA"]
# Out:
# 0    8.2
# 1    7.4
# 2    9.1
# Name: CGPA, dtype: float64

# %%
df[df["CGPA"] > 8]
# Out:
#     Name  CGPA  Package
# 0  Alice   8.2       12
# 2   John   9.1       18

# %%
students = pd.Series(
    [8.9, 7.5, 9.1],
    index=["Alice", "Bob", "Charlie"]
)

df
# Out:
#     Name  CGPA  Package
# 0  Alice   8.2       12
# 1    Bob   7.4        8
# 2   John   9.1       18

# %%
students["Bob"]
# Out:
# np.float64(7.5)

# %%
#Reading and Inspecting Data
df = pd.read_csv("/kaggle/input/datasets/somya2115/placement-csv/placement.csv")

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.head(10)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# 5           5   7.1   48.0          1
# 6           6   5.7  143.0          0
# 7           7   5.0   63.0          0
# 8           8   6.1  156.0          0
# 9           9   5.1   66.0          0

# %%
df.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
df.sample(5) #Random data
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 9            9   5.1   66.0          0
# 64          64   7.0   64.0          1
# 5            5   7.1   48.0          1
# 58          58   8.0   79.0          1
# 72          72   7.3  116.0          1

# %%
df.shape
# Out:
# (100, 4)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'cgpa', 'iq', 'placement'], dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# cgpa          float64
# iq            float64
# placement       int64
# dtype: object

# %%
df.info() #Very used
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
df.isnull().sum() #By this, missing datas can be identified
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
# ==========================================
# Dataset Inspection Checklist
# ==========================================

# Display the first 5 rows of the dataset
# df.head()

# Display the last 5 rows of the dataset
# df.tail()

# Display 5 random rows from the dataset
# df.sample(5)

# Display the shape of the dataset
# Output: (number_of_rows, number_of_columns)
# df.shape

# Display all column names
# df.columns

# Display the data type of each column
# df.dtypes

# Display complete dataset information
# Includes:
# - Number of rows
# - Number of columns
# - Non-null values
# - Data types
# - Memory usage
# df.info()

# Display statistical summary of numerical columns
# Includes:
# - Count
# - Mean
# - Standard Deviation
# - Minimum
# - 25th Percentile
# - Median (50%)
# - 75th Percentile
# - Maximum
# df.describe()

# Display the total number of missing (NaN) values in each column
# df.isnull().sum()

# Display the total number of duplicate rows
# df.duplicated().sum()

# ==========================================
# Categorical Column Inspection
# (Replace "column_name" with an actual column)
# ==========================================

# Display all unique values in a column
# Example:
# df["gender"].unique()

# Display the total number of unique values
# Example:
# df["gender"].nunique()

# Display the frequency of each unique value
# Example:
# Male      120
# Female     80
# df["column_name"].value_counts()

# %%
#Selecting Data (COLUMNS)

# %%
df["cgpa"]
# Out:
# 0     6.8
# 1     5.9
# 2     5.3
# 3     7.4
# 4     5.8
#      ...
# 95    4.3
# 96    4.4
# 97    6.7
# 98    6.3
# 99    6.2
# Name: cgpa, Length: 100, dtype: float64

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df[["cgpa", "iq"]]
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
#Selecting Data (ROWS)

# %%
df.iloc[0] #iloc = Integer Location
# Out:
# Unnamed: 0      0.0
# cgpa            6.8
# iq            123.0
# placement       1.0
# Name: 0, dtype: float64

# %%
df.iloc[1]
# Out:
# Unnamed: 0      1.0
# cgpa            5.9
# iq            106.0
# placement       0.0
# Name: 1, dtype: float64

# %%
df.iloc[:3] #First 3 Rows
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0

# %%
#Selecting Rows and Columns

# %%
df.iloc[:3, 1] #First 3 rows only CGPA
# Out:
# 0    6.8
# 1    5.9
# 2    5.3
# Name: cgpa, dtype: float64

# %%
df.iloc[:5,[1,2]] #First 5 rows, CGPA and IQ
# Out:
#    cgpa     iq
# 0   6.8  123.0
# 1   5.9  106.0
# 2   5.3  121.0
# 3   7.4  132.0
# 4   5.8  142.0

# %%
#Boolean Indexing

# %%
df[df["cgpa"] > 8]
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 37          37   8.1  149.0          1
# 53          53   8.3  168.0          1
# 65          65   8.1  166.0          1
# 69          69   8.5  120.0          1

# %%
df[
(df["cgpa"] > 8) & (df["iq"] > 150)
]
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 53          53   8.3  168.0          1
# 65          65   8.1  166.0          1

# %%
#Sorting

# %%
df.sort_values("cgpa")
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 17          17   3.3  183.0          0
# 50          50   3.5  233.0          0
# 31          31   3.9  109.0          0
# 18          18   4.0  100.0          0
# 68          68   4.0   75.0          0
# ..         ...   ...    ...        ...
# 58          58   8.0   79.0          1
# 65          65   8.1  166.0          1
# 37          37   8.1  149.0          1
# 53          53   8.3  168.0          1
# 69          69   8.5  120.0          1
#
# [100 rows x 4 columns]

# %%
df.sort_values("cgpa", ascending=False)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 69          69   8.5  120.0          1
# 53          53   8.3  168.0          1
# 37          37   8.1  149.0          1
# 65          65   8.1  166.0          1
# 58          58   8.0   79.0          1
# ..         ...   ...    ...        ...
# 18          18   4.0  100.0          0
# 68          68   4.0   75.0          0
# 31          31   3.9  109.0          0
# 50          50   3.5  233.0          0
# 17          17   3.3  183.0          0
#
# [100 rows x 4 columns]

# %%
#Unique Values

# %%
df["cgpa"].unique()
# Out:
# array([6.8, 5.9, 5.3, 7.4, 5.8, 7.1, 5.7, 5. , 6.1, 5.1, 6. , 6.9, 5.4,
#        6.4, 5.2, 3.3, 4. , 6.6, 4.9, 4.7, 7. , 7.6, 3.9, 4.8, 8.1, 6.5,
#        4.6, 7.5, 3.5, 8.3, 7.8, 8. , 7.3, 6.3, 8.5, 6.7, 4.4, 4.3, 6.2])

# %%
df["cgpa"].nunique() #Total number of UNIQUE
# Out:
# 39

# %%
df["cgpa"].value_counts()
# Out:
# cgpa
# 4.9    6
# 6.1    5
# 5.2    5
# 6.0    5
# 7.0    5
# 5.7    4
# 6.8    4
# 7.3    4
# 5.4    4
# 6.5    4
# 4.8    4
# 7.5    3
# 4.7    3
# 5.1    3
# 6.3    3
# 5.0    3
# 6.9    3
# 4.0    2
# 7.1    2
# 5.3    2
# 4.4    2
# 5.8    2
# 6.4    2
# 6.7    2
# 8.1    2
# 6.6    2
# 7.6    2
# 7.4    1
# 5.9    1
# 3.9    1
# 3.3    1
# 7.8    1
# 8.3    1
# 3.5    1
# 4.6    1
# 8.5    1
# 8.0    1
# 4.3    1
# 6.2    1
# Name: count, dtype: int64

# %%
df[["cgpa"]] #DataFrame
# Out:
#     cgpa
# 0    6.8
# 1    5.9
# 2    5.3
# 3    7.4
# 4    5.8
# ..   ...
# 95   4.3
# 96   4.4
# 97   6.7
# 98   6.3
# 99   6.2
#
# [100 rows x 1 columns]

# %%
df["cgpa"] #Series
# Out:
# 0     6.8
# 1     5.9
# 2     5.3
# 3     7.4
# 4     5.8
#      ...
# 95    4.3
# 96    4.4
# 97    6.7
# 98    6.3
# 99    6.2
# Name: cgpa, Length: 100, dtype: float64

# %%
#Data Cleaning

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
df.dropna() #Removes rows that have missing values
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.fillna(0) #Fill with 0's
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
#Fill with the Mean

# %%
df["cgpa"] = df["cgpa"].fillna(df["cgpa"].mean())

# %%
#Fill with the Most Frequent Value

# %%
df["cgpa"] = df["cgpa"].fillna(df["cgpa"].mode()[0])

# %%
#Duplicated Rows

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
#Changing Data Type

# %%
df["cgpa"] = df["cgpa"].astype(int)

# %%
#Data Transformation and Feature Engineering

# %%
performance_df = pd.read_csv("/kaggle/input/datasets/devansodariya/student-performance-data/student_data.csv")

# %%
performance_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2 = performance_df

df2[["age"]]
# Out:
#      age
# 0     18
# 1     17
# 2     15
# 3     15
# 4     16
# ..   ...
# 390   20
# 391   17
# 392   21
# 393   18
# 394   19
#
# [395 rows x 1 columns]

# %%
#Age after 5 years

df2[["Age after 5 years"]] = df2["age"] + 5

# %%
df2[["Age after 5 years"]] #Feature Engineering
# Out:
#      Age after 5 years
# 0                   23
# 1                   22
# 2                   20
# 3                   20
# 4                   21
# ..                 ...
# 390                 25
# 391                 22
# 392                 26
# 393                 23
# 394                 24
#
# [395 rows x 1 columns]

# %%
df2[["age", "Age after 5 years"]]
# Out:
#      age  Age after 5 years
# 0     18                 23
# 1     17                 22
# 2     15                 20
# 3     15                 20
# 4     16                 21
# ..   ...                ...
# 390   20                 25
# 391   17                 22
# 392   21                 26
# 393   18                 23
# 394   19                 24
#
# [395 rows x 2 columns]

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0     6  123.0          1
# 1            1     5  106.0          0
# 2            2     5  121.0          0
# 3            3     7  132.0          1
# 4            4     5  142.0          0
# ..         ...   ...    ...        ...
# 95          95     4  200.0          0
# 96          96     4   42.0          0
# 97          97     6  182.0          1
# 98          98     6  103.0          1
# 99          99     6  113.0          1
#
# [100 rows x 4 columns]

# %%
#Arithmetic Operations

# %%
df["iq"] = df["iq"] * 1.10
df[["iq"]]
# Out:
#        iq
# 0   135.3
# 1   116.6
# 2   133.1
# 3   145.2
# 4   156.2
# ..    ...
# 95  220.0
# 96   46.2
# 97  200.2
# 98  113.3
# 99  124.3
#
# [100 rows x 1 columns]

# %%
#apply()

# %%
def grade(cgpa):
    if cgpa >= 8:
        return "Excellent"
    elif cgpa >= 7:
        return "Good"
    else:
        return "Average"

df["Performance"] = df["cgpa"].apply(grade)

# %%
df[["cgpa","Performance"]]
# Out:
#     cgpa Performance
# 0      6     Average
# 1      5     Average
# 2      5     Average
# 3      7        Good
# 4      5     Average
# ..   ...         ...
# 95     4     Average
# 96     4     Average
# 97     6     Average
# 98     6     Average
# 99     6     Average
#
# [100 rows x 2 columns]

# %%
#where

df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2["Age Group"] = pd.cut(
    df2["age"],
    bins=[0,20,35,100],
    labels=["Young","Adult","Senior"]
)

# %%
df2[["age", "Age Group"]]
# Out:
#      age Age Group
# 0     18     Young
# 1     17     Young
# 2     15     Young
# 3     15     Young
# 4     16     Young
# ..   ...       ...
# 390   20     Young
# 391   17     Young
# 392   21     Adult
# 393   18     Young
# 394   19     Young
#
# [395 rows x 2 columns]

# %%
#GroupBy and Aggregation

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2.groupby("school")[["age"]].mean()
# Out:
#               age
# school
# GP      16.521490
# MS      18.021739

# %%
df2.groupby("school")[["age"]].count()
# Out:
#         age
# school
# GP      349
# MS       46

# %%
df2.groupby("school")[["age"]].max()
# Out:
#         age
# school
# GP       22
# MS       21

# %%
df2.groupby("school")[["age"]].sum()
# Out:
#          age
# school
# GP      5766
# MS       829

# %%
df2.groupby("school")[["age"]].median()
# Out:
#          age
# school
# GP      16.0
# MS      18.0
